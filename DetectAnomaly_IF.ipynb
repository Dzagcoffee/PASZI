# %% [markdown]
# # `Библиотеки`

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, GroupShuffleSplit
from sklearn.ensemble import IsolationForest
from sklearn.metrics import (
    classification_report,
    roc_auc_score
)

import matplotlib.pyplot as plt

# %% [markdown]
# # `Данные: загрузка и препроцессинг`

# %%
df = pd.read_csv("network_traffic.csv")

df
# Out:
#                       time  source_ip_int  destination_ip_int  source_port  \
# 0      2025-04-07 03:25:53     3232281727           167792955        32237
# 1      2025-04-07 08:38:03     3232236596           167774143        15995
# 2      2025-04-07 04:37:03     3232276946           167832337        65426
# 3      2025-04-07 01:30:53     3232270434           167796473        16433
# 4      2025-04-06 20:58:03     3232267105           167776023        27110
# ...                    ...            ...                 ...          ...
# 10000  2025-04-06 20:40:18     3232250619           167783555        59711
# 10001  2025-04-07 05:20:03     3232295215           167799884        26804
# 10002  2025-04-07 05:24:53     3232292523           167822026        63303
# 10003  2025-04-07 17:11:53     3232252147           167774716        31382
# 10004  2025-04-07 15:34:53     3232293831           167788159        54016
#
#        destination_port  protocol  duration  packet_count  bytes_sent  \
# 0                   995         0  2.910802            74        9200
# 1                   995         0  4.661168            33        4015
# 2                    80         0  1.802558            23        2572
# 3                   993         0  4.126773            92        2993
# 4                   143         2  1.949097            43        4257
# ...                 ...       ...       ...           ...         ...
# 10000             64660         5  9.643456            78       17193
# 10001               995         1  1.425016            91         240
# 10002                23         1  2.121701            43        4877
# 10003               993         1  1.787258            28        6632
# 10004               443         0  3.458926            45        3109
#
#        bytes_received  label  bytes_per_packet
# 0                4879      0        124.324324
# 1                1848      0        121.666667
# 2                3190      0        111.826087
# 3                3000      0         32.532609
# 4                6826      0         99.000000
# ...               ...    ...               ...
# 10000           11333      1        220.423077
# 10001             981      0          2.637363
# 10002            7670      0        113.418605
# 10003             366      0        236.857143
# 10004            9827      0         69.088889
#
# [10005 rows x 12 columns]

# %%
print("Пропущенные значения:")
display(df.isna().sum().sort_values(ascending=False).head(20))
# Out:
# Пропущенные значения:
# time                  0
# source_ip_int         0
# destination_ip_int    0
# source_port           0
# destination_port      0
# protocol              0
# duration              0
# packet_count          0
# bytes_sent            0
# bytes_received        0
# label                 0
# bytes_per_packet      0
# dtype: int64

# %%
print("Распределение количества обычного и аномального трафика:")
df["label"].value_counts(normalize=True) * 100
# Out:
# Распределение количества обычного и аномального трафика:
# label
# 0    79.96002
# 1    20.03998
# Name: proportion, dtype: float64

# %%
print("Дубликаты строк:", df.duplicated().sum())
# Out:
# Дубликаты строк: 0

# %%
df = df.copy()

df["time"] = pd.to_datetime(df["time"], errors="coerce")

df["hour"] = df["time"].dt.hour.astype("Int64")
df["dayofweek"] = df["time"].dt.dayofweek.astype("Int64")
df["time_unix"] = (df["time"].astype("int64") // 10**9).astype("Int64")

if "bytes_per_packet" not in df.columns:
    df["bytes_per_packet"] = df["bytes_sent"] / df["packet_count"].replace(0, np.nan)

df["bytes_total"] = df["bytes_sent"] + df["bytes_received"]
df["bytes_sent_ratio"] = df["bytes_sent"] / df["bytes_total"].replace(0, np.nan)

df = df.replace([np.inf, -np.inf], np.nan)
df = df.dropna(subset=["label"])

df
# Out:
#                      time  source_ip_int  destination_ip_int  source_port  \
# 0     2025-04-07 03:25:53     3232281727           167792955        32237
# 1     2025-04-07 08:38:03     3232236596           167774143        15995
# 2     2025-04-07 04:37:03     3232276946           167832337        65426
# 3     2025-04-07 01:30:53     3232270434           167796473        16433
# 4     2025-04-06 20:58:03     3232267105           167776023        27110
# ...                   ...            ...                 ...          ...
# 10000 2025-04-06 20:40:18     3232250619           167783555        59711
# 10001 2025-04-07 05:20:03     3232295215           167799884        26804
# 10002 2025-04-07 05:24:53     3232292523           167822026        63303
# 10003 2025-04-07 17:11:53     3232252147           167774716        31382
# 10004 2025-04-07 15:34:53     3232293831           167788159        54016
#
#        destination_port  protocol  duration  packet_count  bytes_sent  \
# 0                   995         0  2.910802            74        9200
# 1                   995         0  4.661168            33        4015
# 2                    80         0  1.802558            23        2572
# 3                   993         0  4.126773            92        2993
# 4                   143         2  1.949097            43        4257
# ...                 ...       ...       ...           ...         ...
# 10000             64660         5  9.643456            78       17193
# 10001               995         1  1.425016            91         240
# 10002                23         1  2.121701            43        4877
# 10003               993         1  1.787258            28        6632
# 10004               443         0  3.458926            45        3109
#
#        bytes_received  label  bytes_per_packet  hour  dayofweek   time_unix  \
# 0                4879      0        124.324324     3          0  1743996353
# 1                1848      0        121.666667     8          0  1744015083
# 2                3190      0        111.826087     4          0  1744000623
# 3                3000      0         32.532609     1          0  1743989453
# 4                6826      0         99.000000    20          6  1743973083
# ...               ...    ...               ...   ...        ...         ...
# 10000           11333      1        220.423077    20          6  1743972018
# 10001             981      0          2.637363     5          0  1744003203
# 10002            7670      0        113.418605     5          0  1744003493
# 10003             366      0        236.857143    17          0  1744045913
# 10004            9827      0         69.088889    15          0  1744040093
#
#        bytes_total  bytes_sent_ratio
# 0            14079          0.653456
# 1             5863          0.684803
# 2             5762          0.446373
# 3             5993          0.499416
# 4            11083          0.384102
# ...            ...               ...
# 10000        28526          0.602713
# 10001         1221          0.196560
# 10002        12547          0.388698
# 10003         6998          0.947699
# 10004        12936          0.240337
#
# [10005 rows x 17 columns]

# %% [markdown]
# ## `Выбор фичей`

# %%
target = "label"

drop_cols = ["time", target]
drop_cols = [c for c in drop_cols if c in df.columns]

X = df.drop(columns=drop_cols).copy()
y = df[target].astype(int).values

X = X.apply(pd.to_numeric, errors="coerce")
X = X.replace([np.inf, -np.inf], np.nan).fillna(0.0)

for c in ["source_ip_int", "destination_ip_int"]:
    if c in X.columns:
        X = X.drop(columns=[c])

X_values = X.values.astype(np.float32)

# %% [markdown]
# # `Разделение на train/test и обучение`

# %%
X_train_all, X_test, y_train_all, y_test = train_test_split(
    X_values, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
X_train_norm = X_train_all[y_train_all == 0]
print("train_all:", X_train_all.shape, "train_norm:", X_train_norm.shape, "test:", X_test.shape)
# Out:
# train_all: (8004, 13) train_norm: (6400, 13) test: (2001, 13)

# %%
cont = float((y_train_all == 1).mean())
cont = max(min(cont, 0.3), 0.001)
print("contamination:", cont)

iso = IsolationForest(
    n_estimators=500,
    max_samples=256,
    contamination=cont,
    max_features=1.0,
    random_state=42,
    n_jobs=-1
)
# Out:
# contamination: 0.20039980009995004

# %%
iso.fit(X_train_norm)
# Out:
# IsolationForest(contamination=0.20039980009995004, max_samples=256,
#                 n_estimators=500, n_jobs=-1, random_state=42)

# %% [markdown]
# # `Качество классификации`

# %%
# чем больше anomaly_score, тем более аномально
anomaly_score = -iso.score_samples(X_test)

# для ROC нужно, чтобы больше = более класс 1 (аномалия)
roc = roc_auc_score(y_test, anomaly_score)

print(f"ROC-AUC: {roc:.4f}")
# Out:
# ROC-AUC: 0.9684
